# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.io.wavfile as wav

# %%
clap_file = "1.wav"
rate, data = wav.read(clap_file)

plt.plot(data)

# %%
l, r = 1500, 9000
xs = np.arange(l, r)
p = data[l:r] / 2
plt.plot(p)

# %%
wav.write("11.wav", rate, data // 2)
